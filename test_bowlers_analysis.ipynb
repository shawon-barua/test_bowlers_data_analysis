# %% [markdown]
# <br> This notebook will
# <br>1. import the wickets.csv file in your jupyter notebook.
# <br>2. Display the first 10 rows of the dataframe
# <br>3. Create a markdown cell and explain the meaning of each column
# <br>4. find the number of rows and columns in the dataframe
# <br>5. find the data statistics and check for the data types
# <br>6. Are there any missing values present in the dataset?
# <br>7. Rename the column names appropriately
# <br>8. Remove a column from the dataframe
# <br>9. Remove the columns BBI and BBM.
# <br>10. How many players played for ICC?
# <br>11. How many different countries are present in this dataset?
# <br>12. Which player(s) had played for the longest period of time?
# <br>13. Which player(s) had played for the shortest period of time?
# <br>14. How many Australian Bowlers are present in this dataset?
# <br>15. Is there any Bangladeshi player present in this dataset?
# <br>16. Which player had the lowest economy rate?
# <br>17. Which player had the lowest strike rate?
# <br>18. Which player had the lowest bowling average?

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("wickets.csv", encoding = "ISO-8859-1")

display(df.head(10))
# Out:
#                     Player       Span   Mat  Inns  Balls   Runs  Wkts    BBI  \
# 0  M Muralitharan (ICC/SL)  1992-2010   133   230  44039  18180   800   9/51
# 1           SK Warne (AUS)  1992-2007   145   273  40705  17995   708   8/71
# 2        JM Anderson (ENG)  2003-2021  164*   304  35079  16575   623   7/42
# 3         A Kumble (INDIA)  1990-2008   132   236  40850  18355   619  10/74
# 4         GD McGrath (AUS)  1993-2007   124   243  29248  12186   563   8/24
# 5          SCJ Broad (ENG)  2007-2021   149   274  29863  14590   524   8/15
# 6            CA Walsh (WI)  1984-2001   132   242  30019  12688   519   7/37
# 7            DW Steyn (SA)  2004-2019    93   171  18608  10077   439   7/51
# 8      N Kapil Dev (INDIA)  1978-1994   131   227  27740  12867   434   9/83
# 9        HMRKB Herath (SL)  1999-2018    93   170  25993  12157   433  9/127
#
#       BBM    Ave  Econ    SR   5  10
# 0  16/220  22.72  2.47  55.0  67  22
# 1  12/128  25.41  2.65  57.4  37  10
# ...

# %% [markdown]
# <br> Column Details
# <br> Column Player :  Player Name
# <br> Span : Playing time
# <br> Mat: Total Match played
# <br> Inns : Total Innings he batted , every test match has two innings but sometime do not need to bat
# <br> Balls : Total ball faced
# <br> Runs : Total runs scored
# <br> Wkts : Wicket taken
# <br> BBI : Best bowling figure in a innings
# <br> BBM : Best bowling figure in a match
# <br> Ave : Number of run given for per wicket
# <br> Econ : Number of run given for per over
# <br> SR : total balls bowled / wickets taken by bowler
# <br> 5 : 5 wicket taken total
# <br> 10 : 10 wicket taken total

# %%
# number of rows
print("number of rows = ", df.shape[0])

# number of columns
print("number of columns = ", df.shape[1])
# Out:
# number of rows =  79
# number of columns =  14

# %%
# checking for missing values and data types of each column
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     object
#  3   Inns    79 non-null     int64
#  4   Balls   79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   Wkts    79 non-null     int64
#  7   BBI     79 non-null     object
#  8   BBM     79 non-null     object
#  9   Ave     79 non-null     float64
#  10  Econ    79 non-null     float64
#  11  SR      79 non-null     float64
#  12  5       79 non-null     int64
#  13  10      79 non-null     int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 8.8+ KB
# None

# %% [markdown]
# No there is no missing values.

# %%
# checking data statistics
display(df.describe())
# Out:
#              Inns         Balls          Runs        Wkts        Ave  \
# count   79.000000     79.000000     79.000000   79.000000  79.000000
# mean   144.911392  18638.354430   8599.354430  317.215190  27.469747
# std     51.180222   7199.256972   3085.168807  121.924911   3.655658
# min     67.000000   8785.000000   4846.000000  200.000000  20.940000
# 25%    110.000000  13583.000000   6456.500000  229.000000  24.500000
# 50%    129.000000  16498.000000   7742.000000  266.000000  28.000000
# 75%    169.000000  21742.500000   9756.000000  374.500000  29.870000
# max    304.000000  44039.000000  18355.000000  800.000000  34.790000
#
#             Econ         SR          5         10
# count  79.000000  79.000000  79.000000  79.000000
# mean    2.806835  59.193671  16.354430   2.797468
# std     0.351577   9.350132   9.642372   3.235935
# min     1.980000  41.200000   3.000000   0.000000
# 25%     2.600000  53.300000   9.500000   1.000000
# ...

# %%
# column names
print(df.columns)
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Balls', 'Runs', 'Wkts', 'BBI', 'BBM',
#        'Ave', 'Econ', 'SR', '5', '10'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Balls', 'Runs', 'Wkts', 'BBI', 'BBM',
#        'Ave', 'Econ', 'SR', '5', '10'],
#       dtype='object')

# %%
df = df.rename(columns={'Mat':'Match',
                        'Span': 'Playing Time',
                        'Wkts' : 'Total wickets taken',
                        'BBI': 'Best Bowling In a Innings',
                        'BBM' : 'Best Bowling In a Match',
                        'Inns':'Innings',
                        'HS': 'Highest_score',
                        'Ave': 'Average',
                        '10': '10 wicket match',
                        '5': '5 wicket match',
                        'Econ': 'Economy Rate',
                        'SR' : 'Strike Rate',
                       })

display(df.head())
# Out:
#                     Player Playing Time Match  Innings  Balls   Runs  \
# 0  M Muralitharan (ICC/SL)    1992-2010   133      230  44039  18180
# 1           SK Warne (AUS)    1992-2007   145      273  40705  17995
# 2        JM Anderson (ENG)    2003-2021  164*      304  35079  16575
# 3         A Kumble (INDIA)    1990-2008   132      236  40850  18355
# 4         GD McGrath (AUS)    1993-2007   124      243  29248  12186
#
#    Total wickets taken Best Bowling In a Innings Best Bowling In a Match  \
# 0                  800                      9/51                  16/220
# 1                  708                      8/71                  12/128
# 2                  623                      7/42                   11/71
# 3                  619                     10/74                  14/149
# 4                  563                      8/24                   10/27
#
#    Average  Economy Rate  Strike Rate  5 wicket match  10 wicket match
# ...

# %%
df.drop('Strike Rate', axis=1, inplace=True)

# %%
display(df.head())
# Out:
#                     Player Playing Time Match  Innings  Balls   Runs  \
# 0  M Muralitharan (ICC/SL)    1992-2010   133      230  44039  18180
# 1           SK Warne (AUS)    1992-2007   145      273  40705  17995
# 2        JM Anderson (ENG)    2003-2021  164*      304  35079  16575
# 3         A Kumble (INDIA)    1990-2008   132      236  40850  18355
# 4         GD McGrath (AUS)    1993-2007   124      243  29248  12186
#
#    Total wickets taken Best Bowling In a Innings Best Bowling In a Match  \
# 0                  800                      9/51                  16/220
# 1                  708                      8/71                  12/128
# 2                  623                      7/42                   11/71
# 3                  619                     10/74                  14/149
# 4                  563                      8/24                   10/27
#
#    Average  Economy Rate  5 wicket match  10 wicket match
# ...

# %%
df = pd.read_csv("wickets.csv", encoding = "ISO-8859-1")

display(df.head(5))
# Out:
#                     Player       Span   Mat  Inns  Balls   Runs  Wkts    BBI  \
# 0  M Muralitharan (ICC/SL)  1992-2010   133   230  44039  18180   800   9/51
# 1           SK Warne (AUS)  1992-2007   145   273  40705  17995   708   8/71
# 2        JM Anderson (ENG)  2003-2021  164*   304  35079  16575   623   7/42
# 3         A Kumble (INDIA)  1990-2008   132   236  40850  18355   619  10/74
# 4         GD McGrath (AUS)  1993-2007   124   243  29248  12186   563   8/24
#
#       BBM    Ave  Econ    SR   5  10
# 0  16/220  22.72  2.47  55.0  67  22
# 1  12/128  25.41  2.65  57.4  37  10
# 2   11/71  26.60  2.83  56.3  30   3
# 3  14/149  29.65  2.69  65.9  35   8
# 4   10/27  21.64  2.49  51.9  29   3

# %% [markdown]
#  Remove the columns BBI and BBM.

# %%
df.drop(['BBI', 'BBM'], axis=1, inplace=True)

# %%
display(df.head(2))
# Out:
#                     Player       Span  Mat  Inns  Balls   Runs  Wkts    Ave  \
# 0  M Muralitharan (ICC/SL)  1992-2010  133   230  44039  18180   800  22.72
# 1           SK Warne (AUS)  1992-2007  145   273  40705  17995   708  25.41
#
#    Econ    SR   5  10
# 0  2.47  55.0  67  22
# 1  2.65  57.4  37  10

# %%
def icc_check(x):
    if "ICC" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_ICC'] = df['Player'].apply(icc_check)

# %%
df['played_for_ICC'].value_counts()
played_ICC=(df['played_for_ICC']=='Yes').sum()
print("Total played for ICC =" ,played_ICC)
# Out:
# Total played for ICC = 5

# %%
df.drop('played_for_ICC', axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                     Player       Span   Mat  Inns  Balls   Runs  Wkts    Ave  \
# 0  M Muralitharan (ICC/SL)  1992-2010   133   230  44039  18180   800  22.72
# 1           SK Warne (AUS)  1992-2007   145   273  40705  17995   708  25.41
# 2        JM Anderson (ENG)  2003-2021  164*   304  35079  16575   623  26.60
# 3         A Kumble (INDIA)  1990-2008   132   236  40850  18355   619  29.65
# 4         GD McGrath (AUS)  1993-2007   124   243  29248  12186   563  21.64
#
#    Econ    SR   5  10
# 0  2.47  55.0  67  22
# 1  2.65  57.4  37  10
# 2  2.83  56.3  30   3
# 3  2.69  65.9  35   8
# 4  2.49  51.9  29   3

# %%
# renaming the column names
df = df.rename(columns={'Mat':'Match', 
                        'Inns':'Innings',
                        'Wkts': 'Wickets',
                        'Ave': 'Average',
                        '10': '10 Wickets',
                        '5': '5 Wickets',
                        'SR': 'Strike Rate',
                        'Econ': 'Economy Rate'})

# splitting the 'Player' column to get the information about 'Country'
df_player = df['Player'].str.split("(", expand=True)

# concatinating 'Country' with the main dataframe
df = pd.concat([df, df_player], axis=1)

# dropping the 'Player' columns
df = df.drop('Player', axis=1)

# renaming the column names
df = df.rename(columns={0: 'Player',
                        1: 'Country'})

# remove the ")" from the 'Country' column
df['Country'] = df['Country'].str.replace(")", "")
df.head(2)
# rearrange the columns
new_col_sequence = ['Player', 'Span', 'Match', 'Innings','Balls', 'Runs', 'Wickets',
                    'Average', 'Economy Rate', 'Strike Rate','5 Wickets','10 Wickets','Country']
df = df[new_col_sequence]

display(df.head())
# Out:
# G:\Anaconda3\envs\tensorflow2-gpu\lib\site-packages\ipykernel_launcher.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#             Player       Span Match  Innings  Balls   Runs  Wickets  Average  \
# 0  M Muralitharan   1992-2010   133      230  44039  18180      800    22.72
# 1        SK Warne   1992-2007   145      273  40705  17995      708    25.41
# 2     JM Anderson   2003-2021  164*      304  35079  16575      623    26.60
# 3        A Kumble   1990-2008   132      236  40850  18355      619    29.65
# 4      GD McGrath   1993-2007   124      243  29248  12186      563    21.64
#
#    Economy Rate  Strike Rate  5 Wickets  10 Wickets Country
# 0          2.47         55.0         67          22  ICC/SL
# 1          2.65         57.4         37          10     AUS
# ...

# %%
df['Country'] = df['Country'].str.replace("ICC/", "")

display(df.head())
# Out:
#             Player       Span Match  Innings  Balls   Runs  Wickets  Average  \
# 0  M Muralitharan   1992-2010   133      230  44039  18180      800    22.72
# 1        SK Warne   1992-2007   145      273  40705  17995      708    25.41
# 2     JM Anderson   2003-2021  164*      304  35079  16575      623    26.60
# 3        A Kumble   1990-2008   132      236  40850  18355      619    29.65
# 4      GD McGrath   1993-2007   124      243  29248  12186      563    21.64
#
#    Economy Rate  Strike Rate  5 Wickets  10 Wickets Country
# 0          2.47         55.0         67          22      SL
# 1          2.65         57.4         37          10     AUS
# 2          2.83         56.3         30           3     ENG
# 3          2.69         65.9         35           8   INDIA
# 4          2.49         51.9         29           3     AUS

# %%
df['Country'].value_counts()
n = df.Country.nunique()
  
print("No.of.unique Country :",n)
# Out:
# No.of.unique Country : 14

# %%
# splitting the 'Span' column based on the "-"
df_span = df['Span'].str.split("-", expand=True)

# conccatinating the new dataframe with the main dataframe
df = pd.concat([df, df_span], axis=1)

# renaming the newly created column names
df = df.rename(columns={0: "start_year",
                        1: "end_year"})

# removing the "Span" column
df = df.drop("Span", axis=1)

display(df.head())
# Out:
#             Player Match  Innings  Balls   Runs  Wickets  Average  \
# 0  M Muralitharan    133      230  44039  18180      800    22.72
# 1        SK Warne    145      273  40705  17995      708    25.41
# 2     JM Anderson   164*      304  35079  16575      623    26.60
# 3        A Kumble    132      236  40850  18355      619    29.65
# 4      GD McGrath    124      243  29248  12186      563    21.64
#
#    Economy Rate  Strike Rate  5 Wickets  10 Wickets Country start_year  \
# 0          2.47         55.0         67          22      SL       1992
# 1          2.65         57.4         37          10     AUS       1992
# 2          2.83         56.3         30           3     ENG       2003
# 3          2.69         65.9         35           8   INDIA       1990
# 4          2.49         51.9         29           3     AUS       1993
#
#   end_year
# 0     2010
# 1     2007
# 2     2021
# 3     2008
# 4     2007

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        79 non-null     object
#  1   Match         79 non-null     object
#  2   Innings       79 non-null     int64
#  3   Balls         79 non-null     int64
#  4   Runs          79 non-null     int64
#  5   Wickets       79 non-null     int64
#  6   Average       79 non-null     float64
#  7   Economy Rate  79 non-null     float64
#  8   Strike Rate   79 non-null     float64
#  9   5 Wickets     79 non-null     int64
#  10  10 Wickets    79 non-null     int64
#  11  Country       79 non-null     object
#  12  start_year    79 non-null     object
#  13  end_year      79 non-null     object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 8.8+ KB

# %%
df['start_year'] = df['start_year'].astype('int') 
df['end_year'] = df['end_year'].astype('int')

# %%
df['years_played'] = df['end_year'] - df['start_year']

df = df.drop(['start_year', "end_year"], axis=1)

display(df.head(10))
# Out:
#             Player Match  Innings  Balls   Runs  Wickets  Average  \
# 0  M Muralitharan    133      230  44039  18180      800    22.72
# 1        SK Warne    145      273  40705  17995      708    25.41
# 2     JM Anderson   164*      304  35079  16575      623    26.60
# 3        A Kumble    132      236  40850  18355      619    29.65
# 4      GD McGrath    124      243  29248  12186      563    21.64
# 5       SCJ Broad    149      274  29863  14590      524    27.84
# 6        CA Walsh    132      242  30019  12688      519    24.44
# 7        DW Steyn     93      171  18608  10077      439    22.95
# 8     N Kapil Dev    131      227  27740  12867      434    29.64
# 9    HMRKB Herath     93      170  25993  12157      433    28.07
#
#    Economy Rate  Strike Rate  5 Wickets  10 Wickets Country  years_played
# 0          2.47         55.0         67          22      SL            18
# 1          2.65         57.4         37          10     AUS            15
# ...

# %%
df['years_played']= df['years_played'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Player        79 non-null     object
#  1   Match         79 non-null     object
#  2   Innings       79 non-null     int64
#  3   Balls         79 non-null     int64
#  4   Runs          79 non-null     int64
#  5   Wickets       79 non-null     int64
#  6   Average       79 non-null     float64
#  7   Economy Rate  79 non-null     float64
#  8   Strike Rate   79 non-null     float64
#  9   5 Wickets     79 non-null     int64
#  10  10 Wickets    79 non-null     int64
#  11  Country       79 non-null     object
#  12  years_played  79 non-null     int32
# dtypes: float64(3), int32(1), int64(6), object(3)
# memory usage: 7.8+ KB

# %%
df['years_played'].max()
# Out:
# 21

# %%
df[['years_played']].idxmax()
# Out:
# years_played    21
# dtype: int64

# %%
df.iloc[20:25]
# Out:
#            Player Match  Innings  Balls   Runs  Wickets  Average  \
# 20  Waqar Younis     87      154  16224   8788      373    23.56
# 21    Imran Khan     88      142  19458   8258      362    22.81
# 22    DL Vettori    113      187  28814  12441      362    34.36
# 23     DK Lillee     70      132  18467   8493      355    23.92
# 24    WPUJC Vaas    111      194  23438  10501      355    29.58
#
#     Economy Rate  Strike Rate  5 Wickets  10 Wickets Country  years_played
# 20          3.25         43.4         22           5     PAK            14
# 21          2.54         53.7         23           6     PAK            21
# 22          2.59         79.5         20           3      NZ            17
# 23          2.75         52.0         23           7     AUS            13
# 24          2.68         66.0         12           2      SL            15

# %%
print("The player(s) had played for the longest period of time is :",df['Player'][21])
# Out:
# The player(s) had played for the longest period of time is : Imran Khan

# %%
df[['years_played']].idxmin()
# Out:
# years_played    44
# dtype: int64

# %%
print("The player(s) had played for the shortest period of time is :",df['Player'][44])
# Out:
# The player(s) had played for the longest period of time is : GP Swann

# %%
df.iloc[40:45]
# Out:
#              Player Match  Innings  Balls  Runs  Wickets  Average  \
# 40  Danish Kaneria     61      112  17697  9082      261    34.79
# 41        J Garner     58      111  13169  5433      259    20.97
# 42    JN Gillespie     71      137  14234  6770      259    26.13
# 43        MA Starc     61      117  12575  7031      255    27.57
# 44        GP Swann     60      109  15349  7642      255    29.96
#
#     Economy Rate  Strike Rate  5 Wickets  10 Wickets Country  years_played
# 40          3.07         67.8         15           2     PAK            10
# 41          2.47         50.8          7           0      WI            10
# 42          2.85         54.9          8           0     AUS            10
# 43          3.35         49.3         13           2     AUS            10
# 44          2.98         60.1         17           3     ENG             5

# %%
print("Total Australian Bowlers are present in this dataset :",(df['Country']=='AUS').sum())
# Out:
# Total Australian Bowlers are present in this dataset : 18

# %%
print("Total Bangladeshi Bowlers are present in this dataset :",(df['Country']=='BDESH').sum())
# Out:
# Total Bangladeshi Bowlers are present in this dataset : 1

# %%
df[['Economy Rate']].idxmin()
# Out:
# Economy Rate    32
# dtype: int64

# %%
print("The player that had the lowest economy rate:",df['Player'][32])
# Out:
# The player that had the lowest economy rate: LR Gibbs

# %%
df[['Strike Rate']].idxmin()
# Out:
# Strike Rate    71
# dtype: int64

# %%
print("The player that had the lowest strike  rate:",df['Player'][71])
# Out:
# The player that had the lowest strike  rate: K Rabada

# %%
print("Index The player that had the lowest bowling  average:",df[['Average']].idxmin())
# Out:
# Index The player that had the lowest bowling  average: Average    19
# dtype: int64

# %%
print("The player that had the lowest bowling  average:",df['Player'][19])
# Out:
# The player that had the lowest bowling  average: MD Marshall

# %%
df.iloc[19:32]
# Out:
#            Player Match  Innings  Balls   Runs  Wickets  Average  \
# 19   MD Marshall     81      151  17584   7876      376    20.94
# 20  Waqar Younis     87      154  16224   8788      373    23.56
# 21    Imran Khan     88      142  19458   8258      362    22.81
# 22    DL Vettori    113      187  28814  12441      362    34.36
# 23     DK Lillee     70      132  18467   8493      355    23.92
# 24    WPUJC Vaas    111      194  23438  10501      355    29.58
# 25     AA Donald     72      129  15519   7344      330    22.25
# 26    RGD Willis     90      165  17357   8190      325    25.20
# 27    TG Southee     79      148  17886   8862      314    28.22
# 28    MG Johnson     73      140  16001   8891      313    28.40
# 29        Z Khan     92      165  18785  10247      311    32.94
# 30         B Lee     76      150  16531   9554      310    30.81
# 31      M Morkel     86      160  16498   8550      309    27.66
#
# ...
